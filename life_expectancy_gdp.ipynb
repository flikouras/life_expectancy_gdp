# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading and inspecting the Dataset
df = pd.read_csv("all_data.csv")

print(df.groupby("Country").head())
# Out:
#                      Country  Year  Life expectancy at birth (years)  \
# 0                      Chile  2000                              77.3
# 1                      Chile  2001                              77.3
# 2                      Chile  2002                              77.8
# 3                      Chile  2003                              77.9
# 4                      Chile  2004                              78.0
# 16                     China  2000                              71.7
# 17                     China  2001                              72.2
# 18                     China  2002                              72.7
# 19                     China  2003                              73.1
# 20                     China  2004                              73.5
# 32                   Germany  2000                              78.0
# 33                   Germany  2001                              78.3
# 34                   Germany  2002                              78.4
# ...

# %%
df.rename(columns = {'Life expectancy at birth (years)':'Life_Expectancy'}, inplace = True)
df2 = df[df.Country != 'Zimbabwe']

# %%
plt.figure(figsize = (15,10))
sns.boxplot(data = df2,x = 'Country', y = 'Life_Expectancy')
plt.show()
plt.clf
# Out:
# <function matplotlib.pyplot.clf()>

# %%
plt.figure(figsize = (9,10))
sns.scatterplot(data = df[df.Year == 2000],x = 'GDP', y = 'Life_Expectancy',hue = 'Country')

# %%
df.head()
# Out:
#   Country  Year  Life_expectancy           GDP
# 0   Chile  2000             77.3  7.786093e+10
# 1   Chile  2001             77.3  7.097992e+10
# 2   Chile  2002             77.8  6.973681e+10
# 3   Chile  2003             77.9  7.564346e+10
# 4   Chile  2004             78.0  9.921039e+10

# %%
plt.figure(figsize = (10,6))
plt.bar(x = df.Country,height = df.Life_Expectancy)
# Out:
# <BarContainer object of 96 artists>
